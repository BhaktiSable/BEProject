# %%
import pandas as pd 
import numpy as np

# %%
data=pd.read_csv('databasefinal.csv')
# Out:
# C:\Users\nehab\AppData\Local\Temp\ipykernel_18068\2601321835.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv('databasefinal.csv')

# %%
data.head(5)
# Out:
#    courseID                                           title  \
# 0         1                                  创业101: 你的客户是谁？
# 1         2                                创业102: 你能为客户做什么？
# 2         3             18th-Century Opera: Handel & Mozart
# 3         4  19th-Century Opera: Meyerbeer, Wagner, & Verdi
# 4         5                                          3D GIS
#
#                                                  url  \
# 0                   https://www.edx.org/course/101-2
# 1                   https://www.edx.org/course/102-2
# 2  https://www.edx.org/course/18th-century-opera-...
# 3  https://www.edx.org/course/19th-century-opera-...
# 4                  https://www.edx.org/course/3d-gis
#
#                                           categories  \
# 0                              Business & Management
# 1                              Business & Management
# 2                      Art & Culture, History, Music
# 3                      Art & Culture, History, Music
# ...

# %%
data=data[data.subtitle == 'English']

# %%
data.head(5)
# Out:
#                                             title  \
# 2             18th-Century Opera: Handel & Mozart
# 3  19th-Century Opera: Meyerbeer, Wagner, & Verdi
# 4                                          3D GIS
# 5         3D Modeling from Architectural Drawings
# 6                           4G Network Essentials
#
#                                                  url  \
# 2  https://www.edx.org/course/18th-century-opera-...
# 3  https://www.edx.org/course/19th-century-opera-...
# 4                  https://www.edx.org/course/3d-gis
# 5  https://www.edx.org/course/3d-modeling-from-ar...
# 6   https://www.edx.org/course/4g-network-essentials
#
#                                           categories  \
# 2                      Art & Culture, History, Music
# 3                      Art & Culture, History, Music
# 4  Data Analysis & Statistics, Energy & Earth Sci...
# 5                               Architecture, Design
# 6                      Computer Science, Engineering
#
# ...

# %%
data.drop(columns='courseID',inplace=True)

# %%
data.drop(columns='popularity_index',inplace=True)

# %%
data.tail(5)
# Out:
#                                                    title  \
# 87695  Limit Sugar Sweetened Beverages to Not More Th...
# 87696  Limit Processed Foods to Not More Than One Ser...
# 87697    how to be an expert in the word of bodybuilding
# 87698  Meditation - The Art of Inner Peace and Happin...
# 87699  Aim for a Resting Heart Rate Below 60 Beats Pe...
#
#                                                      url  \
# 87695  https://www.udemy.com/course/limit-sugar-sweet...
# 87696  https://www.udemy.com/course/limit-processed-f...
# 87697  https://www.udemy.com/course/how-to-be-an-expe...
# 87698  https://www.udemy.com/course/meditation-the-ar...
# 87699  https://www.udemy.com/course/aim-for-a-resting...
#
#                                        categories  \
# 87695                  Health & Fitness,Nutrition
# 87696                  Health & Fitness,Nutrition
# 87697             Health & Fitness,Fitness,Health
# 87698                 Health & Fitness,Meditation
# ...

# %%
data.categories.unique
# Out:
# <bound method Series.unique of 2                            Art & Culture, History, Music
# 3                            Art & Culture, History, Music
# 4        Data Analysis & Statistics, Energy & Earth Sci...
# 5                                     Architecture, Design
# 6                            Computer Science, Engineering
#                                ...
# 87695                           Health & Fitness,Nutrition
# 87696                           Health & Fitness,Nutrition
# 87697                      Health & Fitness,Fitness,Health
# 87698                          Health & Fitness,Meditation
# 87699           Health & Fitness,General Health,Healthcare
# Name: categories, Length: 67202, dtype: object>

# %%
df=data[data.platform == 1]
df.categories[4000:7000]
# Out:
# 13217                     Design,Other Design,2D Animation
# 13219       Design,Graphic Design & Illustration,Photoshop
# 13220    Design,Graphic Design & Illustration,Adobe Ill...
# 13221     Design,Graphic Design & Illustration,Logo Design
# 13222                                   Design Tools,Figma
#                                ...
# 16991                       Business,Management,Leadership
# 16992                   Business,Other Business,QuickBooks
# 16993              Business,Entrepreneurship,Home Business
# 16995                        Business,Entrepreneurship,ICO
# 16996        Business,Entrepreneurship,Presentation Skills
# Name: categories, Length: 3000, dtype: object

# %%
categorylist=['Computer Science','Data Analysis & Statistics','Language','Engineering','Math','Data Science','Information Technology','Math and Logic','Web Development','Mobile Development','Programming Languages','Game Development','Database Design & Development','Software Testing','Software Engineering','Software Development Tools','No-Code Development','Design','Web Design','3D & Animation','Game Design','Mobile App Design','Adobe','IT Certifications','Network & Security','Operating Systems & Servers','Other IT & Software']

# %%
df1 = data[data.categories.str.contains('|'.join(categorylist))]

# %%
df1.shape
# Out:
# (24782, 16)

# %%
df1.categories.head(30)
# Out:
# 4     Data Analysis & Statistics, Energy & Earth Sci...
# 5                                  Architecture, Design
# 6                         Computer Science, Engineering
# 7                                      Computer Science
# 8                              Computer Science, Design
# 9                              Computer Science, Ethics
# 10     Architecture, Data Analysis & Statistics, Design
# 12                   Business & Management, Engineering
# 14    Business & Management, Communication, Engineering
# 15    Business & Management, Communication, Engineering
# 16    Business & Management, Communication, Engineering
# 20                                          Engineering
# 23                                                 Math
# 24                                                 Math
# 25                                                 Math
# 26                                                 Math
# 28                                 Engineering, Science
# ...

# %%
discard=['Art','Architecture','Teaching & Academics','Health','Music','History','Health & Fitness','Nutrition','Healthcare','Entrepreneurship','Business','Management','Leadership']

# %%
df1 = df1[~df1.categories.str.contains('|'.join(discard))]

# %%
df1.shape
# Out:
# (21192, 16)

# %%
df1[677:1000]
# Out:
#                                                   title  \
# 1801    Nanotechnology: Fundamentals of Nanotransistors
# 1802                       National Accounts Statistics
# 1803  Natural Disaster and Climate Change Risk Asses...
# 1805  Natural Language Processing and Language Under...
# 1810             Nature, in Code: Biology in JavaScript
# ...                                                 ...
# 2970  Alibaba Cloud Native Solutions and Container S...
# 3005                   Analyze Data to Answer Questions
# 3007  Analyze Datasets and Train ML Models using AutoML
# 3023  Analyzing a Tennis Serve with the Video Intell...
# 3043               Animation with JavaScript and jQuery
#
#                                                     url  \
# 1801  https://www.edx.org/course/nanotechnology-fund...
# 1802  https://www.edx.org/course/national-accounts-s...
# 1803  https://www.edx.org/course/natural-disaster-an...
# 1805  https://www.edx.org/course/natural-language-pr...
# ...

# %%
df1['platform'].replace(0,'Edx',inplace=True)
df1[677:1000]
# Out:
#                                                   title  \
# 1801    Nanotechnology: Fundamentals of Nanotransistors
# 1802                       National Accounts Statistics
# 1803  Natural Disaster and Climate Change Risk Asses...
# 1805  Natural Language Processing and Language Under...
# 1810             Nature, in Code: Biology in JavaScript
# ...                                                 ...
# 2970  Alibaba Cloud Native Solutions and Container S...
# 3005                   Analyze Data to Answer Questions
# 3007  Analyze Datasets and Train ML Models using AutoML
# 3023  Analyzing a Tennis Serve with the Video Intell...
# 3043               Animation with JavaScript and jQuery
#
#                                                     url  \
# 1801  https://www.edx.org/course/nanotechnology-fund...
# 1802  https://www.edx.org/course/national-accounts-s...
# 1803  https://www.edx.org/course/natural-disaster-an...
# 1805  https://www.edx.org/course/natural-language-pr...
# ...

# %%
df1['platform'].replace(1, 'Udemy',inplace=True)
df1['platform'].replace(2, 'Coursera',inplace=True)

# %%
df1.to_csv('Edx_coursera_udemy_edited1.csv', index=False, encoding='utf_8_sig')

# %%
cousera_df=df1[df1.platform=='Coursera']
cousera_df.shape
# Out:
# (666, 16)

# %%
edx_df=df1[df1.platform=='Edx']
edx_df.shape
# Out:
# (946, 16)

# %%
udemy_df=df1[df1.platform=='Udemy']
udemy_df.shape
# Out:
# (19580, 16)

# %%
cousera_df.to_csv('Coursera_edited1.csv', index=False, encoding='utf_8_sig')

# %%
udemy_df.to_csv('udemy_edited1.csv', index=False, encoding='utf_8_sig')

# %%
edx_df.to_csv('Edx_edited1.csv', index=False, encoding='utf_8_sig')
